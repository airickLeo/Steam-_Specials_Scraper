# %% [markdown]
# # This script scrapes the top sellers of special deals on steam
#
# Contains the game name, the original price and the discounted price, the percentage of discount, the game rating and number of votes, the tags of the game, and the release year
#
# https://youtu.be/oKk3dplKLVg
# https://stackoverflow.com/questions/69425134/i-am-trying-to-scrape-multiple-pages-using-beautfiul-soup-but-the-code-keeps-ret
# https://stackoverflow.com/questions/48490940/beautifulsoup-steam-market-web-scraping-errors

# %%
import requests
import csv
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import concurrent.futures
import threading
import time
import json

# %%
# Obtain the source
api_url = "https://store.steampowered.com/contenthub/querypaginated/specials/TopSellers/render/?query=&start=0&count=15&cc=CA&l=english&v=4&tag="

# %%
# Get the data (only the resulting html page from JSON)
def get_data(url):
    r = requests.get(url)
    # Store the data as a dictionary
    data = dict(r.json())
    return data['results_html']

print(get_data(api_url))
# Out:
# 	<a href="https://store.steampowered.com/app/597180/Old_World/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-appid="597180" data-ds-itemkey="App_597180" data-ds-tagids="[9,4364,1670,1741,3987,1678,1708]" data-ds-crtrids="[33019866,38719421]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:597180,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/apps/597180/capsule_184x69.jpg?t=1653035882" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="4499"><div class="discount_pct">-10%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 49.99</div><div class="discount_final_price">CDN$ 44.99</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">Old World</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span>				<div class="tab_item_top_tags"><span class="top_tag">Strategy</span><span class="top_tag">, Grand Strategy</span><span class="top_tag">, 4X</span><span class="top_tag">, Turn-Based Strategy</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>
# 		<a href="https://store.steampowered.com/app/1594940/Little_Witch_in_the_Woods/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-appid="1594940" data-ds-itemkey="App_1594940" data-ds-tagids="[493,4726,3964,122,4057,4136,1654]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:1594940,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/apps/1594940/capsule_184x69.jpg?t=1652934089" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="1664"><div class="discount_pct">-10%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 18.49</div><div class="discount_final_price">CDN$ 16.64</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">Little Witch in the Woods</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span><span class="platform_img mac"></span>				<div class="tab_item_top_tags"><span class="top_tag">Early Access</span><span class="top_tag">, Cute</span><span class="top_tag">, Pixel Graphics</span><span class="top_tag">, RPG</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>
# 		<a href="https://store.steampowered.com/app/987840/Expeditions_Rome/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-appid="987840" data-ds-itemkey="App_987840" data-ds-tagids="[122,9,10695,1741,4474,14139,21725]" data-ds-descids="[5]" data-ds-crtrids="[7564110]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:987840,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/apps/987840/capsule_184x69.jpg?t=1652256396" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="3374"><div class="discount_pct">-25%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 44.99</div><div class="discount_final_price">CDN$ 33.74</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">Expeditions: Rome</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span>				<div class="tab_item_top_tags"><span class="top_tag">RPG</span><span class="top_tag">, Strategy</span><span class="top_tag">, Party-Based RPG</span><span class="top_tag">, Turn-Based Strategy</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>
# 		<a href="https://store.steampowered.com/app/495420/State_of_Decay_2_Juggernaut_Edition/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-appid="495420" data-ds-itemkey="App_495420" data-ds-tagids="[1662,1695,1659,7332,1685,3859,3843]" data-ds-descids="[2,5]" data-ds-crtrids="[3090835]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:495420,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/apps/495420/capsule_184x69_alt_assets_1.jpg?t=1653000634" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="1319"><div class="discount_pct">-67%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 39.99</div><div class="discount_final_price">CDN$ 13.19</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">State of Decay 2: Juggernaut Edition</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span>				<div class="tab_item_top_tags"><span class="top_tag">Survival</span><span class="top_tag">, Open World</span><span class="top_tag">, Zombies</span><span class="top_tag">, Base Building</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>
# 		<a href="https://store.steampowered.com/app/1158310/Crusader_Kings_III/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-appid="1158310" data-ds-itemkey="App_1158310" data-ds-tagids="[9,122,599,4364,4172,3987,4853]" data-ds-crtrids="[4117016,6859167,36592959]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:1158310,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/capsule_184x69.jpg?t=1650534761" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="4559"><div class="discount_pct">-20%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 56.99</div><div class="discount_final_price">CDN$ 45.59</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">Crusader Kings III</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span>				<div class="tab_item_top_tags"><span class="top_tag">Strategy</span><span class="top_tag">, RPG</span><span class="top_tag">, Simulation</span><span class="top_tag">, Grand Strategy</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>
# 		<a href="https://store.steampowered.com/app/1506830/FIFA_22/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-appid="1506830" data-ds-itemkey="App_1506830" data-ds-tagids="[1679,701,3859,3878,599,7226,7368]" data-ds-crtrids="[36135791,38196776]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:1506830,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/apps/1506830/capsule_184x69.jpg?t=1644868577" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="1279"><div class="discount_pct">-84%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 79.99</div><div class="discount_final_price">CDN$ 12.79</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">FIFA 22</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span>				<div class="tab_item_top_tags"><span class="top_tag">Soccer</span><span class="top_tag">, Sports</span><span class="top_tag">, Multiplayer</span><span class="top_tag">, Competitive</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>
# 		<a href="https://store.steampowered.com/app/394360/Hearts_of_Iron_IV/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-appid="394360" data-ds-itemkey="App_394360" data-ds-tagids="[9,4150,4364,3987,1678,4168,4598]" data-ds-crtrids="[4117016,6859167,39012884]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:394360,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/apps/394360/capsule_184x69.jpg?t=1652356929" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="1099"><div class="discount_pct">-75%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 43.99</div><div class="discount_final_price">CDN$ 10.99</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">Hearts of Iron IV</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span>				<div class="tab_item_top_tags"><span class="top_tag">Strategy</span><span class="top_tag">, World War II</span><span class="top_tag">, Grand Strategy</span><span class="top_tag">, Historical</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>
# 		<a href="https://store.steampowered.com/sub/452685/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-packageid="452685" data-ds-appid="1158310,1296731,1303182,1303183,1303184" data-ds-itemkey="Sub_452685" data-ds-tagids="[9,122,599,4172,4364,3987]" data-ds-crtrids="[4117016,6859167,36592959]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;sub&quot;,&quot;id&quot;:452685,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/subs/452685/capsule_184x69.jpg?t=1615914297" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="7739"><div class="discount_pct">-10%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 85.99</div><div class="discount_final_price">CDN$ 77.39</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">Crusader Kings III Royal Edition</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span>				<div class="tab_item_top_tags"><span class="top_tag">Strategy</span><span class="top_tag">, RPG</span><span class="top_tag">, Simulation</span><span class="top_tag">, Medieval</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>
# 		<a href="https://store.steampowered.com/app/753640/Outer_Wilds/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-appid="753640" data-ds-itemkey="App_753640" data-ds-tagids="[3834,1755,5716,21,1742,4166,1756]" data-ds-crtrids="[33023506]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:753640,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/apps/753640/capsule_184x69.jpg?t=1651528790" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="1739"><div class="discount_pct">-40%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 28.99</div><div class="discount_final_price">CDN$ 17.39</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">Outer Wilds</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span>				<div class="tab_item_top_tags"><span class="top_tag">Exploration</span><span class="top_tag">, Space</span><span class="top_tag">, Mystery</span><span class="top_tag">, Adventure</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>
# 		<a href="https://store.steampowered.com/app/393380/Squad/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-appid="393380" data-ds-itemkey="App_393380" data-ds-tagids="[4168,4175,1663,3859,1708,1774,1678]" data-ds-crtrids="[33965189]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:393380,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/apps/393380/capsule_184x69.jpg?t=1649877267" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="4499"><div class="discount_pct">-25%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 59.99</div><div class="discount_final_price">CDN$ 44.99</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">Squad</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span>				<div class="tab_item_top_tags"><span class="top_tag">Military</span><span class="top_tag">, Realistic</span><span class="top_tag">, FPS</span><span class="top_tag">, Multiplayer</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>
# 		<a href="https://store.steampowered.com/app/255710/Cities_Skylines/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-appid="255710" data-ds-itemkey="App_255710" data-ds-tagids="[4328,599,1643,12472,9,3810,4182]" data-ds-crtrids="[6859167]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:255710,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/apps/255710/capsule_184x69.jpg?t=1649170845" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="824"><div class="discount_pct">-75%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 32.99</div><div class="discount_final_price">CDN$ 8.24</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">Cities: Skylines</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span>				<div class="tab_item_top_tags"><span class="top_tag">City Builder</span><span class="top_tag">, Simulation</span><span class="top_tag">, Building</span><span class="top_tag">, Management</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>
# 		<a href="https://store.steampowered.com/app/1522090/Stellaris_Nemesis/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-appid="1522090" data-ds-itemkey="App_1522090" data-ds-tagids="[9,599,4364,1670,4711,4295,7107]" data-ds-crtrids="[4117016,6859167]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:1522090,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/apps/1522090/capsule_184x69.jpg?t=1652374437" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="1595"><div class="discount_pct">-30%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 22.79</div><div class="discount_final_price">CDN$ 15.95</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">Stellaris: Nemesis</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span>				<div class="tab_item_top_tags"><span class="top_tag">Strategy</span><span class="top_tag">, Simulation</span><span class="top_tag">, Grand Strategy</span><span class="top_tag">, 4X</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>
# 		<a href="https://store.steampowered.com/app/1922560/Plants_vs_Zombies_Garden_Warfare_2_Deluxe_Edition/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-appid="1922560" data-ds-itemkey="App_1922560" data-ds-tagids="[620519,3814,1775,4136,1659,19,1774]" data-ds-crtrids="[37140667,36135791,36140475]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:1922560,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/apps/1922560/capsule_184x69.jpg?t=1652720468" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="1000"><div class="discount_pct">-75%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 39.99</div><div class="discount_final_price">CDN$ 10.00</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">Plants vs. Zombies™ Garden Warfare 2: Deluxe Edition</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span>				<div class="tab_item_top_tags"><span class="top_tag">Hero Shooter</span><span class="top_tag">, Third-Person Shooter</span><span class="top_tag">, PvP</span><span class="top_tag">, Funny</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>
# 		<a href="https://store.steampowered.com/app/281990/Stellaris/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-appid="281990" data-ds-itemkey="App_281990" data-ds-tagids="[1755,4364,9,3942,1670,3834,3810]" data-ds-crtrids="[4117016,6859167]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:281990,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/apps/281990/capsule_184x69_alt_assets_3.jpg?t=1652979714" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="880"><div class="discount_pct">-80%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 43.99</div><div class="discount_final_price">CDN$ 8.80</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">Stellaris</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span>				<div class="tab_item_top_tags"><span class="top_tag">Space</span><span class="top_tag">, Grand Strategy</span><span class="top_tag">, Strategy</span><span class="top_tag">, Sci-fi</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>
# 		<a href="https://store.steampowered.com/app/1527950/Wartales/?snr=1_2300_4__104_1" class="tab_item  "  data-ds-appid="1527950" data-ds-itemkey="App_1527950" data-ds-tagids="[122,1695,1741,21,4172,9,3834]" data-ds-descids="[2,5]" data-ds-crtrids="[32964953,41387478]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:1527950,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )">
# 		<div class="tab_item_cap">
# 			<img class="tab_item_cap_img" src="https://cdn.cloudflare.steamstatic.com/steam/apps/1527950/capsule_184x69.jpg?t=1648076669" >
# 		</div>
# 				<div class="discount_block tab_item_discount" data-price-final="3199"><div class="discount_pct">-20%</div><div class="discount_prices"><div class="discount_original_price">CDN$ 39.99</div><div class="discount_final_price">CDN$ 31.99</div></div></div>		<div class="tab_item_content">
# 			<div class="tab_item_name">Wartales</div>
# 			<div class="tab_item_details">
# 				<span class="platform_img win"></span>				<div class="tab_item_top_tags"><span class="top_tag">RPG</span><span class="top_tag">, Open World</span><span class="top_tag">, Turn-Based Strategy</span><span class="top_tag">, Adventure</span></div>
# 			</div>
# 		</div>
# 		<div style="clear: both;"></div>
# 	</a>

# %%
# Get the total number of results
def total_results(url):
    r = requests.get(url)
    # Store the data as a dictionary
    data = dict(r.json())
    total_results = data['total_count']
    return int(total_results)

total_results = total_results(api_url)
total_results
# Out:
# 1579

# %%
# Get the number of games per page
def page_size(url):
    r = requests.get(url)
    # Store the data as a dictionary
    data = dict(r.json())
    page_size = data['pagesize']
    return int(page_size)

games_per_page = page_size(api_url)
games_per_page
# Out:
# 15

# %%
# Parse to get all the game details
def parse(url):
    
    game_list = []
    
    soup = BeautifulSoup(url, 'lxml')
    # Since the get_data function filtered out all anchor texts
    games = soup.find_all('a')
    for game in games:
        title = game.find('div', class_ = 'tab_item_name').text.replace(":", "")
        cur_before_disc = game.find('div', class_ = 'discount_original_price').text.strip().replace("CND$", "")
        cur_before_disc = cur_before_disc.replace("CDN$", "")
        
        try:
            cur_discount_pct = game.find('div', class_ = 'discount_pct').text.replace("-", "").replace("%", "")
            cur_after_disc = game.find('div', class_ = 'discount_final_price').text
            cur_after_disc = cur_after_disc.replace("CDN$", "")
            
        except:
            cur_discount_pct = 0
            cur_after_disc = cur_before_disc
        
        link = game['href']
        game_list.append([title, cur_before_disc, cur_discount_pct, cur_after_disc, link])
        
    return game_list

# %%
# Create a list to store all the API queries
pages = []

for x in range(0, total_results, games_per_page):
    pages.append(f"https://store.steampowered.com/contenthub/querypaginated/specials/TopSellers/render/?query=&start={x}&count=15&cc=CA&l=english&v=4&tag=")
    
with concurrent.futures.ThreadPoolExecutor() as executor:
    results = executor.map(get_data, pages)
    
pages = list(results)

# %%
# Create a threading pool and feed the queries to BeautifulSoup
with concurrent.futures.ThreadPoolExecutor() as executor:
    results = executor.map(parse, pages)

# Create a final list to convert into DataFrame
final_list = []
    
for result in results:
    final_list += result
    
final_list = pd.DataFrame(final_list, columns = ['Name', 'Before Discount $', 
                                                 "Discount Percentage %", 'After Discount $', 'Link'])
final_list
# Out:
#                                        Name Before Discount $  \
# 0                                 Old World             49.99
# 1                 Little Witch in the Woods             18.49
# 2                          Expeditions Rome             44.99
# 3       State of Decay 2 Juggernaut Edition             39.99
# 4                        Crusader Kings III             56.99
# ...                                     ...               ...
# 1573                            Rift's Cave              1.19
# 1574                              Tetropunk              3.99
# 1575  Zombie Killer Drift - Racing Survival              5.69
# 1576           MechDefender - Tower Defense              5.69
# 1577           Two Sedans Driving Simulator              1.19
#
#      Discount Percentage % After Discount $  \
# 0                       10            44.99
# 1                       10            16.64
# 2                       25            33.74
# 3                       67            13.19
# 4                       20            45.59
# ...                    ...              ...
# 1573                    50             0.59
# 1574                    85             0.59
# 1575                    90             0.56
# 1576                    90             0.56
# 1577                    50             0.59
#
#                                                    Link
# 0     https://store.steampowered.com/app/597180/Old_...
# 1     https://store.steampowered.com/app/1594940/Lit...
# 2     https://store.steampowered.com/app/987840/Expe...
# 3     https://store.steampowered.com/app/495420/Stat...
# 4     https://store.steampowered.com/app/1158310/Cru...
# ...                                                 ...
# 1573  https://store.steampowered.com/app/335210/Rift...
# 1574  https://store.steampowered.com/app/540190/Tetr...
# 1575  https://store.steampowered.com/app/1720950/Zom...
# 1576  https://store.steampowered.com/app/562730/Mech...
# 1577  https://store.steampowered.com/app/1917720/Two...
#
# [1578 rows x 5 columns]

# %%
# Export to CSV
final_list.to_csv('Games Special.csv', index = False)
